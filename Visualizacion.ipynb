# %% [markdown]
# <a href="https://colab.research.google.com/github/niklena/first/blob/master/Visualizacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy.special
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt #import matplotlib as plt
from bokeh.resources import Kind
# Our main plotting package (must have explicit import of submodules)
import bokeh.io
import bokeh.plotting
#pandas.bokeh.output_notebook
# https://joserzapata.github.io/courses/python-ciencia-datos/visualizacion/

# Enable viewing Bokeh plots in the notebook
bokeh.io.output_notebook()

GRD_sheet=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Datos.xls',sheet_name='GRD',header=0,index_col=None)
Hosp_sheet=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Datos.xls',sheet_name='Hospitales',header=0,index_col=None)
Info_sheet=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Datos.xls',sheet_name='Información Histórica',header=0,index_col=None)
#GRD_sheet.head()
Hosp_sheet.head()
#p_pie = Info_sheet[['Número de llegada','GRD']].groupby('GRD').count().plot_bokeh.pie(show_figure=False)
#p_line=Info_sheet[['Número de llegada','Día de llegada']].groupby('Día de llegada').count().plot_bokeh(kind="line")
#pandas_bokeh.plot_grid([[p_line,p_pie]],plot_width=450)
#_x_values_original
#p_scatter=Hosp_sheet.groupby(['Nombre Servicio de Salud']).mean().plot_bokeh(kind="scatter",y="Costo de instalar una cama [MM$]",color='blue',plot_data_points= True,show_figure=False)
#p_bar= GRD_sheet.plot_bokeh(kind="barh", y = "Costo resolución en Clinica Privada [MM$]",color='#d01c8b',plot_data_points=True,show_figure=False)
#p_line= Info_sheet[['GRD','Estadia']].groupby('GRD').mean().plot_bokeh(kind='line',show_figure=False)
#p_pie= GRD_INFO.plot_bokeh.pie(y="Conteo",show_figute=False)

# Question 1 ¿Cuál código permite hacer un gráfico de línea de las llegadas históricas del GRD4 en el hospital San Juan de Dios?
apoyo1 = Info_sheet.loc[(Info_sheet["Hospital al que llega"] == "Hospital San Juan de Dios") & (Info_sheet["GRD"] == "GRD4")]
apoyo1 = apoyo1[["Hospital al que llega", "Día de llegada"]].groupby("Día de llegada").count()
print(apoyo1)
apoyo1.plot(kind="line", legend = None, figsize = (10,3))
plt.xlim([414, 423])
# Out:
#                 Hospital al que llega
# Día de llegada
# 2                                   1
# 6                                   2
# 7                                   3
# 8                                   1
# 9                                   1
# ...                               ...
# 414                                 4
# 416                                 1
# 417                                 2
# 420                                 1
# 423                                 2
#
# [232 rows x 1 columns]
# (414.0, 423.0)

# %% [markdown]
# # 2. Question 2 ¿Cuál de las siguientes alternativas corresponde al código que permite construir un gráfico de línea con las llegadas históricas por día para el GRD4? (y entonces, agrupando cada día las llegadas a todos los hospitales)

# %%
apoyo2 = Info_sheet.loc[Info_sheet["GRD"] == "GRD4"]

apoyo2 = apoyo2[["Hospital al que llega", "Día de llegada"]].groupby("Hospital al que llega").count()

apoyo2.plot(kind="line", legend = None, figsize = (15,5))
# Out:
# <Axes: xlabel='Día de llegada'>

# %% [markdown]
# 3. Question 3 ¿Qué código permite hacer un gráfico de línea para las llegadas históricas en toda la red?

# %%
apoyo3 = Info_sheet[["Hospital al que llega", "Día de llegada"]].groupby("Día de llegada").count()

apoyo3.plot(kind="line", legend = None, figsize = (15,5))
# Out:
# <Axes: xlabel='Día de llegada'>

# %%
apoyo4a = Info_sheet.loc[Info_sheet["GRD"] == "GRD4"]

apoyo4a = apoyo4a[["Hospital al que llega", "Día de llegada"]].groupby("Hospital al que llega").count()

apoyo4b = Info_sheet.loc[Info_sheet["GRD"] == "GRD3"]

apoyo4b = apoyo4b[["Hospital al que llega", "Día de llegada"]].groupby("Hospital al que llega").count()

# %% [markdown]
# # Question 7 ¿Cuál código permite realizar un gráfico de dispersión sobre el costo de resolución en el sistema de salud privado?

# %%
#GRD_sheet.plot(kind = "boxplot", x = "ID GRD", y = "Costo resolución en Clínica Privada [MM$]", figsize = (10,5))


#GRD_sheet.plot(kind = "line", x = "ID GRD", y = "Costo resolución en Clínica Privada [MM$]", figsize = (10,5))


#GRD_sheet.plot(kind = "hist", x = "ID GRD", y = "Costo resolución en Clínica Privada [MM$]", figsize = (10,5))


GRD_sheet.plot(kind = "scatter", x = "ID GRD", y = "Costo resolución en Clínica Privada [MM$]", figsize = (10,5))
# Out:
# <Axes: xlabel='ID GRD', ylabel='Costo resolución en Clínica Privada [MM$]'>

# %% [markdown]
# Question 9 Considerando solamente el total de pacientes atendidos (llegada de pacientes) registrado en los últimos 10 días, ¿cuál de las siguientes alternativas corresponde al código para hacer un gráfico de barras que muestre la proporción (medida en porcentaje) de pacientes con cada GRD respecto del total de pacientes?

# %%
apoyo9 = Info_sheet.loc[Info_sheet["Día de llegada"] >= 414]

apoyo9["GRD"].value_counts(normalize = True, sort = True).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
apoyo9 = Info_sheet.loc[Info_sheet["Día de llegada"]]

apoyo9["GRD"].value_counts(normalize = True, sort = True).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
apoyo9 = Info_sheet[Info_sheet["Día de llegada"] >= 414]

apoyo9["GRD"].value_counts(normalize = True, sort = True).plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# ¿Cuál es el servicio de salud con mayor costo anual de operación de camas, al realizar un gráfico de barras para obtener el resultado?

# %%
# For Data Analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# For Data Visualization
import plotly.express as px
import plotly.io as pio

# Addidtional Imports
from termcolor import colored
# import country_converter as coco
import datetime
import calendar
